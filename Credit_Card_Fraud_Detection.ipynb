# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
train_data = pd.read_csv('/content/fraudTrain.csv')
test_data = pd.read_csv('/content/fraudTest.csv')

# %%
train_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
train_data.tail()
# Out:
#          Unnamed: 0 trans_date_trans_time            cc_num  \
# 1219623     1219623   2020-05-25 03:43:39      639077309909
# 1219624     1219624   2020-05-25 03:44:49      571844099986
# 1219625     1219625   2020-05-25 03:45:12   180069253480336
# 1219626     1219626   2020-05-25 03:45:48  4191109180926792
# 1219627     1219627   2020-05-25 03:46:05     4471568287204
#
#                                     merchant      category     amt     first  \
# 1219623                 fraud_O'Keefe-Hudson   grocery_pos   70.40    Justin
# 1219624                    fraud_Paucek-Wiza   grocery_net   60.75     Susan
# 1219625                fraud_Eichmann-Russel      misc_pos    2.25   William
# 1219626                   fraud_Bauch-Raynor   grocery_pos  198.80  Jennifer
# 1219627  fraud_Bahringer, Schoen and Corkery  shopping_pos    9.38    Dakota
#
#               last gender                         street  ...      lat  \
# ...

# %%
test_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
test_data.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                      merchant        category     amt    first     last  \
# 555714  fraud_Reilly and Sons  health_fitness   43.77  Michael    Olson
# 555715   fraud_Hoppe-Parisian       kids_pets  111.84     Jose  Vasquez
# 555716        fraud_Rau-Robel       kids_pets   86.88      Ann   Lawson
# 555717  fraud_Breitenberg LLC          travel    7.99     Eric  Preston
# 555718      fraud_Dare-Marvin   entertainment   38.13   Samuel     Frey
#
#        gender                      street  ...      lat      long  city_pop  \
# 555714      M         558 Michael Estates  ...  40.4931  -91.8912       519
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1219628 entries, 0 to 1219627
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1219628 non-null  int64
#  1   trans_date_trans_time  1219628 non-null  object
#  2   cc_num                 1219628 non-null  int64
#  3   merchant               1219628 non-null  object
#  4   category               1219628 non-null  object
#  5   amt                    1219628 non-null  float64
#  6   first                  1219628 non-null  object
#  7   last                   1219628 non-null  object
#  8   gender                 1219628 non-null  object
#  9   street                 1219628 non-null  object
#  10  city                   1219628 non-null  object
#  11  state                  1219628 non-null  object
#  12  zip                    1219628 non-null  int64
#  13  lat                    1219628 non-null  float64
# ...

# %%
train_data.drop(columns = ['Unnamed: 0','trans_date_trans_time', 'merchant', 'category', 'first','last','gender','street','city','state','job','dob','trans_num'],inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1219628 entries, 0 to 1219627
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   cc_num      1219628 non-null  int64
#  1   amt         1219628 non-null  float64
#  2   zip         1219628 non-null  int64
#  3   lat         1219628 non-null  float64
#  4   long        1219628 non-null  float64
#  5   city_pop    1219628 non-null  int64
#  6   unix_time   1219627 non-null  float64
#  7   merch_lat   1219627 non-null  float64
#  8   merch_long  1219627 non-null  float64
#  9   is_fraud    1219627 non-null  float64
# dtypes: float64(7), int64(3)
# memory usage: 93.1 MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
test_data.drop(columns = ['Unnamed: 0','trans_date_trans_time', 'merchant', 'category', 'first','last','gender','street','city','state','job','dob','trans_num'],inplace=True)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   cc_num      555719 non-null  int64
#  1   amt         555719 non-null  float64
#  2   zip         555719 non-null  int64
#  3   lat         555719 non-null  float64
#  4   long        555719 non-null  float64
#  5   city_pop    555719 non-null  int64
#  6   unix_time   555719 non-null  int64
#  7   merch_lat   555719 non-null  float64
#  8   merch_long  555719 non-null  float64
#  9   is_fraud    555719 non-null  int64
# dtypes: float64(5), int64(5)
# memory usage: 42.4 MB

# %% [markdown]
# Checking for missing values

# %%
train_data.isnull().sum()
# Out:
# cc_num        0
# amt           0
# zip           0
# lat           0
# long          0
# city_pop      0
# unix_time     1
# merch_lat     1
# merch_long    1
# is_fraud      1
# dtype: int64

# %%
train_data = train_data.dropna(how = 'any')

# %%
train_data.isnull().sum()
# Out:
# cc_num        0
# amt           0
# zip           0
# lat           0
# long          0
# city_pop      0
# unix_time     0
# merch_lat     0
# merch_long    0
# is_fraud      0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# cc_num        0
# amt           0
# zip           0
# lat           0
# long          0
# city_pop      0
# unix_time     0
# merch_lat     0
# merch_long    0
# is_fraud      0
# dtype: int64

# %%
test_data = test_data.dropna(how = 'any')

# %%
test_data.isnull().sum()
# Out:
# cc_num        0
# amt           0
# zip           0
# lat           0
# long          0
# city_pop      0
# unix_time     0
# merch_lat     0
# merch_long    0
# is_fraud      0
# dtype: int64

# %%
train_data['is_fraud'].value_counts()
# Out:
# is_fraud
# 0.0    1212552
# 1.0       7075
# Name: count, dtype: int64

# %% [markdown]
# Splitting Training and Testing data

# %%
X_train = train_data.drop(columns  = 'is_fraud', axis =1)
Y_train = train_data['is_fraud']
X_test = test_data.drop(columns  = 'is_fraud', axis =1)
Y_test = test_data['is_fraud']

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
#training the logistic regression model with training data
model.fit(X_train,Y_train)

# %% [markdown]
# Model Evaluation - Accuracy Score

# %%
#Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on Training data : ",training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9941990461018

# %%
# Accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print("Accuracy on Test data : ",test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9961401355721147

# %% [markdown]
# Decision Tree

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Model Evaluation - Accuracy Score

# %%
#Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on Training data : ",training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
# Accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print("Accuracy on Test data : ",test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9800996546815927
